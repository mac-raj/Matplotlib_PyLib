# %% [markdown]
# <a href="https://colab.research.google.com/github/mac-raj/Matplotlib_PyLib/blob/main/Matplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Matplot Introduction

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xpoints =np.array([0,10])
ypoints = np.array([0,20])

# %%
plt.plot(xpoints , ypoints,'o')

# %%
xpoints= np.array([1,2,3,4])
ypoints= np.array([3,6,7,10])

# %%
plt.plot(xpoints,ypoints)

# %%
# x take by default 0 1 2 3 4 
xpoints= np.array([10,20,30,40,5])

# %%
plt.plot(ypoints)

# %%
xpoints= np.array([1,2,3,4])
ypoints= np.array([3,6,7,10])
plt.plot(xpoints,ypoints, marker='o')

# %%
xpoints= np.array([1,2,3,4])
ypoints= np.array([3,6,7,10])
plt.plot(xpoints,ypoints, marker='*')

# %%
# marker line and then color
xpoints= np.array([1,2,3,4])
ypoints= np.array([3,6,7,10])
plt.plot(xpoints,ypoints, '*:r')

# %%
xpoints= np.array([1,2,3,4])
ypoints= np.array([3,6,7,10])
plt.plot(xpoints,ypoints, '*:g')

# %%
# marker size
xpoints= np.array([1,2,3,4])
ypoints= np.array([3,6,7,10])
plt.plot(xpoints,ypoints, 'o' , ms=20)

# %%
# marker color
xpoints= np.array([1,2,3,4])
ypoints= np.array([3,6,7,10])
plt.plot(xpoints,ypoints, 'o' , ms=20,mec='r')

# %%
# marker face color 
xpoints= np.array([1,2,3,4])
ypoints= np.array([3,6,7,10])
plt.plot(xpoints,ypoints, 'o' , ms=20,mfc='r')

# %%
xpoints= np.array([1,2,3,4])
ypoints= np.array([3,6,7,10])
plt.plot(xpoints,ypoints, linestyle='dotted')

# %%
xpoints= np.array([1,2,3,4])
ypoints= np.array([3,6,7,10])
plt.plot(xpoints,ypoints, ls=':')

# %%
xpoints= np.array([1,2,3,4])
ypoints= np.array([3,6,7,10])
plt.plot(xpoints,ypoints, color='red')

# %%
xpoints= np.array([1,2,3,4])
ypoints= np.array([3,6,7,10])
plt.plot(ypoints, linewidth = '20.5')

# %%
y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])
plt.plot(y1)
plt.plot(y2)
plt.show()

# %%
x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])
plt.plot(x1, y1, x2, y2)
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.plot(x, y)
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
# Out:
# Text(0, 0.5, 'Calorie Burnage')

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.plot(x, y)
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
# Out:
# Text(0, 0.5, 'Calorie Burnage')

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)
# Out:
# Text(0, 0.5, 'Calorie Burnage')

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.plot(x, y)
plt.grid()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.plot(x, y)
plt.grid(axis = 'x')
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.plot(x, y)
plt.grid(axis = 'y')
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.plot(x, y)
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
plt.show()

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(1, 2, 1)
plt.plot(x,y)
#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(2, 1, 1)
plt.plot(x,y)
#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(2, 1, 2)
plt.plot(x,y)
plt.show()

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")
#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.suptitle("MY SHOP")
# Out:
# Text(0.5, 0.98, 'MY SHOP')

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)
plt.show()

# %%
#day one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

#day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = 'hotpink')

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = '#88c999')

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x, y, c=colors)

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes)

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes, alpha=0.5)

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
# Out:
# <BarContainer object of 4 artists>

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y)
# Out:
# <BarContainer object of 4 artists>

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color = "red")
# Out:
# <BarContainer object of 4 artists>

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, width = 0.1)
# Out:
# <BarContainer object of 4 artists>

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])
plt.barh(x, y, height = 0.1)
# Out:
# <BarContainer object of 4 artists>

# %%
x = np.random.normal(170, 10, 250)

plt.hist(x)
# Out:
# (array([ 7., 15., 25., 52., 47., 52., 33., 15.,  2.,  2.]),
#  array([144.64066009, 150.24246194, 155.84426379, 161.44606563,
#         167.04786748, 172.64966933, 178.25147118, 183.85327302,
#         189.45507487, 195.05687672, 200.65867856]),
#  <a list of 10 Patch objects>)

# %%
y = np.array([35, 25, 25, 15])

plt.pie(y)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f9ad61d6710>,
#   <matplotlib.patches.Wedge at 0x7f9ad61d6bd0>,
#   <matplotlib.patches.Wedge at 0x7f9ad6162210>,
#   <matplotlib.patches.Wedge at 0x7f9ad61622d0>],
#  [Text(0.4993895680663529, 0.9801071672559597, ''),
#   Text(-1.086457168210212, 0.17207795223283895, ''),
#   Text(-0.172077952232839, -1.086457168210212, ''),
#   Text(0.9801071672559598, -0.4993895680663526, '')])

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f9ad6130110>,
#   <matplotlib.patches.Wedge at 0x7f9ad6130610>,
#   <matplotlib.patches.Wedge at 0x7f9ad61305d0>,
#   <matplotlib.patches.Wedge at 0x7f9ad613a210>],
#  [Text(0.4993895680663529, 0.9801071672559597, 'Apples'),
#   Text(-1.086457168210212, 0.17207795223283895, 'Bananas'),
#   Text(-0.172077952232839, -1.086457168210212, 'Cherries'),
#   Text(0.9801071672559598, -0.4993895680663526, 'Dates')])

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels, startangle = 90)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f9ad60fc910>,
#   <matplotlib.patches.Wedge at 0x7f9ad60fcdd0>,
#   <matplotlib.patches.Wedge at 0x7f9ad61073d0>,
#   <matplotlib.patches.Wedge at 0x7f9ad6107490>],
#  [Text(-0.9801071672559597, 0.49938956806635293, 'Apples'),
#   Text(-0.172077952232839, -1.086457168210212, 'Bananas'),
#   Text(1.086457168210212, -0.17207795223283906, 'Cherries'),
#   Text(0.49938956806635265, 0.9801071672559598, 'Dates')])

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f9ad65a7050>,
#   <matplotlib.patches.Wedge at 0x7f9ad693d090>,
#   <matplotlib.patches.Wedge at 0x7f9ad63c0090>,
#   <matplotlib.patches.Wedge at 0x7f9ad63c0910>],
#  [Text(0.5901876713511442, 1.1583084703934068, 'Apples'),
#   Text(-1.086457168210212, 0.17207795223283895, 'Bananas'),
#   Text(-0.172077952232839, -1.086457168210212, 'Cherries'),
#   Text(0.9801071672559598, -0.4993895680663526, 'Dates')])

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f9ad670f490>,
#   <matplotlib.patches.Wedge at 0x7f9ad6ad7910>,
#   <matplotlib.patches.Wedge at 0x7f9ad6a7bdd0>,
#   <matplotlib.patches.Wedge at 0x7f9ad6466110>],
#  [Text(0.5901876713511442, 1.1583084703934068, 'Apples'),
#   Text(-1.086457168210212, 0.17207795223283895, 'Bananas'),
#   Text(-0.172077952232839, -1.086457168210212, 'Cherries'),
#   Text(0.9801071672559598, -0.4993895680663526, 'Dates')])

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
mycolors = ["black", "hotpink", "b", "#4CAF50"]

plt.pie(y, labels = mylabels, colors = mycolors)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f9ad64ee6d0>,
#   <matplotlib.patches.Wedge at 0x7f9ad648b310>,
#   <matplotlib.patches.Wedge at 0x7f9ad66649d0>,
#   <matplotlib.patches.Wedge at 0x7f9ad649d950>],
#  [Text(0.4993895680663529, 0.9801071672559597, 'Apples'),
#   Text(-1.086457168210212, 0.17207795223283895, 'Bananas'),
#   Text(-0.172077952232839, -1.086457168210212, 'Cherries'),
#   Text(0.9801071672559598, -0.4993895680663526, 'Dates')])

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
plt.pie(y, labels = mylabels)
plt.legend(title = "Four Fruits:")
